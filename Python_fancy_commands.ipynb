# %% [markdown]
# <a href="https://colab.research.google.com/github/markoo26/thehappymountain/blob/main/Python_fancy_commands.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title 🔄 Reverse a string

text = "Hello"
print(text[::-1])

# %%
#@title 🚓 Check if a string is palindrome

text = "bob"
text == text[::-1]

# %%
#@title 🧮 Count vowels

text = "Good morning"
sum(c in "aeiou" for c in text.lower())

# %%
#@title 📖 Propercase a.k.a. str.title()

text = "good morning everyone"
text.title()

# %%
#@title 🗺️ Flatten a list

nested_list = [[1,2], [3,4], [5,6], [7,8]]
flat = [x for s in nested_list for x in s]
flat

# %%
#@title 🗑️ Removing duplicates from a list
#@markdown Firstly, create a dict since the same key cannot be duplicated.
#@markdown <br> Then - recreated a list from the dict.
input_list = [1, 1, 6, 2, 3, 4, 5, 6]

print(f"With order preserved: {list(dict.fromkeys(input_list))}")
print(f"With sorting: {list(set(input_list))}")

# %%
#@title 🏆 Get most frequent element in a list
input_list = [1,1,1,1,2,3,4]

print(max(input_list, key=input_list.count))

# %%
#@title 🐍 Get the longest word in a list

words = ['bee', 'cat', 'elephant']

print(max(words, key=len))

# %%
#@title 🏭 Chunking a list

input_list = [1,1,1,1,2,3,4]
n = 3
print([input_list[i:i+n] for i in range(0, len(input_list), n)])

# %%
#@title 🟪 Transpose a matrix

matrix = [[2,4,5], [3,2,1], [10, 20, 30]]
list(zip(*matrix))

# %%
#@title 🛞 Rotate a list

input_list = [1,1,1,1,2,3,4]
k=2

input_list[-k:] + input_list[:-k]

# %%
#@title ⛙ Merge and deduplicate two lists
#@markdown **|** - union
#@markdown <br>**&** - intersection
#@markdown <br>**-** - difference
#@markdown <br>**^** - symmetric difference
list_a = [1,2,3,4,5]
list_b = [2,3,4,5,6,7]

print(f"list_a: {list_a}")
print(f"list_b: {list_b}")

print(f"Union: {list(set(list_a) | set(list_b))}")
print(f"Intersection: {list(set(list_a) & set(list_b))}")
print(f"Difference: {list(set(list_a) - set(list_b))}")
print(f"Symmetric difference: {list(set(list_a) ^ set(list_b))}")

# %%
#@title 🔀 Sort a list
str_list = ['a', 'b', 'd', 'a', 'c', 'g', 'e']
sorted(str_list, reverse = True)

# %%
#@title 🔀 Swap two variables
a = 10
b = 15

b, a = a, b
print(f"""a: {a}, b: {b}""")

# %%
#@title 🗜️Clamp values to <min, max> range

lo = 0
hi = 10
n = -5

print(max(lo, min(n, hi)))

# %%
#@title 😶‍🌫️ Generate range of even numbers
n = 10
print(list(range(0, n, 2)))

# %%
#@title 🧼Check if a number is prime
n = 11
all(n % i != 0 for i in range(2, int(n**0.5)+1)) and n > 1

# %%
#@title 🔢 Fibonacci sequence
n=20

def fibonacci(n):
    a, b = 0, 1
    # while a <= n:
    for _ in range(n):
        yield a
        a, b = b, a + b

list(fibonacci(n))

# %%
#@title ⏪ Invert a dictionary
d = {"Bob": 10, "John": 20}

print({v: k for k, v in d.items()})

# %%
#@title 📲 Merge dictionaries

d1 = {"John": 10, "Bob": 20}
d2 = {"Alice": 30, "Helen": 40}

merged = d1 | d2

print(merged)

merged = {**d1, **d2}
print(merged)

# %%
#@title 🗃️ Sort dict by value

d1 = {"John": 20, "Bob": 100}
d2 = {"Alice": 5, "Helen": 40}

d = d1 | d2

print(dict(sorted(d.items(), key=lambda x: x[1])))
print(dict(sorted(d.items(), key=lambda x: x[0])))

# %%
#@title 🥇 Get key with highest value

d1 = {"John": 100, "Bob": 20}
d2 = {"Alice": 5, "Helen": 40}

d = d1 | d2

print(max(d, key=d.get))

# %%
#@title 🎰 Word frequency counter

s = "this this is is is a very very very very long long sentence"
freq = {w: s.split().count(w) for w in s.split()}
print(freq)

# %%
#@title 🗺️ List and map lambda
input_list = [-1, 0, 1, 5, 10]
list(map(lambda x: x**2, input_list))

# %%
#@title 🛁 List and filter lambda
input_list = [-1, 0, 1, 5, 10]
list(filter(lambda x: x % 2 == 0, input_list))

# %%
#@title 🤐 Zip keys and values into a dict

keys = ['a', 'b', 'c', 'd']
values = [1, 2, 3, 4]
dict(zip(keys, values))

# %%
#@title ⚖️ Unzip a list of tuples
pairs = [(1,2), (3,4), (5, 6)]

keys, values = zip(*pairs)
print(f"keys: {keys}, values: {values}")

# %%
#@title ⚖️ Find commons and differences in two lists
input_list1 = [2,3,4,5]
input_list2 = [4,5,6,7]
print(f"Common elements: {list(set(input_list1) & set(input_list2))}")
print(f"In L1 and not in L2: {list(set(input_list1) - set(input_list2))}")

# %%
#@title ⭐ Check if all elements are unique
input_list = [2,3,4,5,5]
len(input_list) == len(set(input_list))

# %%
#@title 🌯 Unpack first or last element of a list

input_list = [10, 20, 30, 40, 50]
first, *rest = input_list
print(f"First element: {first}, rest: {rest}")
*rest, last = input_list
print(f"First elements: {rest}, last: {last}")

# %%
#@title 🗂️ Multiple assignments

a = b = c = 0

print(f"a: {a}, b: {b}, c: {c}")

# %%
#@title 🖨️ Print list without brackets
input_list = [2, 3, 4, 5]
print(*input_list, sep=', ')

# %%
#@title 🖊️ Write a text file

# %%writefile sample_text.txt

This is a short text.
Its goal is to test different Python one-liner commands.
It's amazing because it's very short

# %%
#@title 🖹 Read and split TXT into lines
lines = open("sample_text.txt").read().splitlines()
lines

# %%
#@title ⏱️ %%timeit for basic optimizations
#@markdown **n** - number of runs within a round
#@markdown <br>**r** - number of rounds

# %%timeit -n 500000 -r 10

def deduplicate_string(string):
    return list(dict.fromkeys(string))

def merge_the_tools(string, k):
    splits = len(string) // k
    split_strings = [deduplicate_string(string[i*k:(i+1)*k]) for i in range(splits)]

    for substring in split_strings:
        return ''.join(substring)

string = 'AABCAAADA'
k=3

merge_the_tools(string, k)

# %%
#@title 💾 Store %timeit into a variable

result = %timeit -o merge_the_tools(string,k)

# %%
#@title 🥊 Building a list and a generator

def squares_list(n):
  return [n**2 for n in range(n)]

def squares_gen(n):
  return (n**2 for n in range(n))

# %%
#@title 💌 Time a list
# %%timeit -n 1000 -r 5
squares_list(10000)

# %%
#@title ⚡ Time generator
# %%timeit -n 1000 -r 5
squares_gen(10000)
